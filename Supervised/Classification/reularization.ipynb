# %%
import numpy as np

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# %%
def gradient_descent(X, y, alpha, iterations, lambda_):
    m,n = X.shape
    w = np.zeros(n)
    b = 0

    for i in range(iterations):
        z = X @ w + b
        f_wb = 1/(1+np.exp(-z))
        error = f_wb - y

        cost = (-1/m)*np.sum(y*np.log(f_wb) + (1-y)*np.log(1-f_wb)) \
               + (lambda_/(2*m)) * np.sum(w**2)

        dj_dw = (1/m)*(X.T@error) + (lambda_/m)*w
        dj_db = (1/m)*np.sum(error)

        w -= alpha * dj_dw
        b -= alpha * dj_db

        if i % 100 == 0:
            print(f"For {i} iterations: Cost = {cost}")

    return w,b

# %%
w, b = gradient_descent(X_train, y_train, alpha = 0.01, iterations=2000, lambda_=20)

print(f"w: {w}, b: {b}")
# Out:
# For 0 iterations: Cost = 0.6931471805599452
# For 100 iterations: Cost = 0.682183842262969
# For 200 iterations: Cost = 0.6814909007091181
# For 300 iterations: Cost = 0.6810182573224008
# For 400 iterations: Cost = 0.6806954073739538
# For 500 iterations: Cost = 0.6804749037978568
# For 600 iterations: Cost = 0.6803243136231079
# For 700 iterations: Cost = 0.6802214750552696
# For 800 iterations: Cost = 0.6801512484110446
# For 900 iterations: Cost = 0.6801032927748155
# For 1000 iterations: Cost = 0.6800705456858204
# For 1100 iterations: Cost = 0.6800481840662714
# For 1200 iterations: Cost = 0.6800329142889586
# For 1300 iterations: Cost = 0.6800224872285554
# For 1400 iterations: Cost = 0.6800153670431737
# For 1500 iterations: Cost = 0.6800105049732271
# For 1600 iterations: Cost = 0.6800071848690199
# For 1700 iterations: Cost = 0.6800049177053481
# For 1800 iterations: Cost = 0.6800033695495503
# For 1900 iterations: Cost = 0.6800023123741716
# w: [0.0719575  0.04898434], b: -0.17018673913396026

# %%
import numpy as np

# %%
def my_softmax(X):
    ez = np.exp(z)
    return ez/np.sum(ez)

# %%
z = np.array([1., 2., 3., 4.])
print(f"my softmax: {my_softmax(z)}")
# Out:
# my softmax: [0.0320586  0.08714432 0.23688282 0.64391426]

# %%
# The softmax function converts raw numerical scores (logits) from a neural network into probabilities that sum to 1.0
# It is primarily used in the final layer of multi-class classification models to make outputs interpretable. 
# It maps values to a (0–1) range, highlighting the highest score while scaling others.

# In the above example output is, my softmax: [0.0320586  0.08714432 0.23688282 0.64391426]
# It's sum = 1
